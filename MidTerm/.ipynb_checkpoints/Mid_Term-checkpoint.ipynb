# %%
# Get data for python
import requests
from requests_oauthlib import OAuth1
import os, json
from time import sleep

pageStr = '1'

while True:
    url ='https://api.stackexchange.com/2.2/questions?page='+pageStr+'&pagesize=100&order=desc&sort=activity&site=stackoverflow&key=f49Nam3UjMJmLs2KHr1jcg(('
    response = requests.get(url)
    response = response.json()
    with open(pageStr+'.json', 'w') as f:
        json.dump(response, f)
    page = int(pageStr) + 1
    pageStr = str(page)
    if page == 2500:
        break
print(page)
# Out:
# 2500

# %% [markdown]
# # Get user id and save it in a file

# %%
print('hi')
# Out:
# hi

# %%
import json, os

path_to_json = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Questions/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]


userId = []
page = 0
for js in json_files:
    with open(os.path.join(path_to_json, js)) as json_file:
        data = json.load(json_file)
    users = data['items']
    for item in users:
        try:
            if item['owner']['user_id'] is not None and item['owner']['user_id'] not in userId:
                userId.append(item['owner']['user_id'])
        except KeyError:
            continue
print(len(userId))
f = open("USERID.txt", "w")
f.write("\n".join(map(lambda x: str(x), userId)))
f.close()
print("The UserID's have been saved in USERID.txt file")
# Out:
# 78961
# The UserID's have been saved in USERID.txt file

# %% [markdown]
# # Remove /n and all the user id's to a list

# %%
file = open('USERID.txt', 'r')
#list = file.readlines()
filelist = [line.rstrip('\n') for line in file] #removal of /n
file.close()
print("User ID's has been added to list")
# Out:
# User ID's has been added to list

# %%
print(filelist[-10:])
# Out:
# ['544025', '1301058', '5956262', '5010639', '388026', '5052976', '2621207', '2604897', '6837932', '4896705']

# %% [markdown]
# # Get user profile for all the user id's in the list

# %%
import os, time
import requests
filepath = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/UserProfile_For_Questions/'
page = 0

first = filelist[]
for file in filelist:
    path = filepath+file+'.json'
    if os.path.isfile(path):
        continue
    else:
        #for id in userId:
            #idStr = str(id)
        url = 'https://api.stackexchange.com/2.2/users/'+file+'?order=desc&sort=reputation&site=stackoverflow&key=f49Nam3UjMJmLs2KHr1jcg(('
        response = requests.get(url)
        response = response.json()
        with open(file+'.json', 'w') as f:
            json.dump(response, f)
            page = page + 1
        time.sleep(1)

print(page)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-49cf97ada0a7> in <module>()
#      11             #idStr = str(id)
#      12         url = 'https://api.stackexchange.com/2.2/users/'+file+'?order=desc&sort=reputation&site=stackoverflow&key=f49Nam3UjMJmLs2KHr1jcg(('
# ---> 13         response = requests.get(url)
#      14         response = response.json()
#      15         with open(file+'.json', 'w') as f:
#
# C:\Users\Priyanka\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      69
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#      73
#
# C:\Users\Priyanka\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ...

# %% [markdown]
# # Get badges of the users who have posted to all the questions which have been collected

# %%
# Ping for user id's for all the questions that has been collected
import requests, json
import time
page = 0
path_of_badges = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Badges/'
# 169643 ids
first = filelist[100:1000]
second = filelist[50000:100000]
third = filelist[100000:169643]
for id in first:
    url = 'https://api.stackexchange.com/2.2/users/'+id+'/badges?order=desc&sort=rank&site=stackoverflow&key=kyGQl9dUXIepqbCHGEqExw(('
    response = requests.get(url)
    response = response.json()
    with open(path_of_badges+id+'.json', 'w') as f:
        json.dump(response, f)
    page = page + 1
    if page % 1000 == 0:
        print(page)
    time.sleep(1)
print("These were the number of user id's:", page)    
print("Badges obtained by the users have been saved in the folder")
# Out:
# These were the number of user id's: 900
# Badges obtained by the users have been saved in the folder

# %% [markdown]
# # Get all the answers to the questions that have been collected

# %%
import requests, json, os
import time

path_to_json = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Questions/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

question_id = []
for js in json_files:
    with open(os.path.join(path_to_json, js)) as json_file:
        data = json.load(json_file)
    questions = data['items']
    for item in questions:
        try:
            if item['question_id'] is not None and item['question_id'] not in questions:
                question_id.append(item['question_id'])
        except KeyError:
            continue
print(len(question_id))
f = open("QUESTIONID.txt", "w")
f.write("\n".join(map(lambda x: str(x), question_id)))
f.close()
print("The Question ID's have been saved in QUESTIONID.txt file")
# Out:
# 99900
# The Question ID's have been saved in QUESTIONID.txt file

# %% [markdown]
# # Remove /n from all the question ID's after reasing from a file and add it to a list

# %%
file = open('QUESTIONID.txt', 'r')
#list = file.readlines()
questionlist = [line.rstrip('\n') for line in file] #removal of /n
file.close()
print("Question ID's has been added to list")
print(len(questionlist))
# Out:
# Question ID's has been added to list
# 99900

# %% [markdown]
# # Get answers to all the question ID's that have been stored in the file

# %%
import os
filepath = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Answers/'
page = 0
first = questionlist[3229:5000]
third = questionlist[100000:99900]

for file in first:
    path = filepath+file+'.json'
    if os.path.isfile(path):
        continue
    else:
        for id in first:
            #idStr = str(id)
            url = 'https://api.stackexchange.com/2.2/questions/'+id+'/answers?order=desc&sort=activity&site=stackoverflow&key=kyGQl9dUXIepqbCHGEqExw(('
            response = requests.get(url)
            response = response.json()
            with open(os.path.join(filepath, id)+'.json', 'w') as f:
                json.dump(response, f)
                page = page + 1
            if page % 1000 == 0:
                print(page)
            time.sleep(1)
print("These were the number of answers collected:", page)    
print("Answers obtained for the questions have been saved in the folder ../Answers")
# Out:
# 1000
# These were the number of answers collected: 1771
# Answers obtained for the questions have been saved in the folder ../Answers

# %% [markdown]
# # Get all the tags

# %%
# Get data for python
import requests
import os, json
from time import sleep

pageStr = '954'
filepath = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Tags/'

while True:
    # url = 'https://api.stackexchange.com/2.2/tags?page=1&pagesize=100&order=desc&sort=popular&site=stackoverflow&key=f49Nam3UjMJmLs2KHr1jcg(('
    url = 'https://api.stackexchange.com/2.2/tags?page='+pageStr+'&pagesize=100&order=desc&sort=popular&site=stackoverflow&key=f49Nam3UjMJmLs2KHr1jcg(('
    response = requests.get(url)
    response = response.json()
    with open(os.path.join(filepath, pageStr)+'.json', 'w') as f:
        json.dump(response, f)
    page = int(pageStr) + 1
    pageStr = str(page)
    if page == 1500:
        break
    time.sleep(1)
print(page)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0374347d647a> in <module>()
#      19     if page == 1500:
#      20         break
# ---> 21     time.sleep(1)
#      22 print(page)
#
# KeyboardInterrupt:

# %% [markdown]
# #                                                    Analysis

# %% [markdown]
# # Analysis 1

# %% [markdown]
# # For the collected questions look for tags("JAVA" , "PYTHON") and get user ID's

# %%
import json, os

path_to_questions = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Questions/'
path_to_user = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/UserProfile_For_Questions/'
json_files = [pos_json for pos_json in os.listdir(path_to_questions) if pos_json.endswith('.json')]


userId_python = []
userId_java = []
page = 0
count = {}
user_badge_count = {}
user_reputation = {}
topweighted_questions_python= {}
topweighted_questions_java= {}
for js in json_files:
    with open(os.path.join(path_to_questions, js)) as json_file:
        data = json.load(json_file)
    users = data['items']
    for tag in users:
        tags = tag['tags']
        #print(tags)
        try:
            for everytag in tags:
                if 'python' in everytag:
                    userId_python.append(tag['owner']['user_id']) # get user id
                    path_user = path_to_user+str(tag['owner']['user_id'])+'.json'
                    with open (path_user,'r') as json_file:
                        data = json.load(json_file)
                    user_badges = data['items']
                    weights = {'gold': 8, 'bronze': 2, 'silver': 4}
                    for item in user_badges:
                        try:
                            count = item['badge_counts']
                            user_reputation[item['user_id']] = item['reputation']

                            weight = 2
                            value = 0
                            for key in count:
                                value = value + weights[key] * count[key]                    
                            user_badge_count[item['user_id']] =  value #sum(count.values())
                            topweighted_questions_python[tag['title']] = value
                        except KeyError:
                            continue
                        page = page + 1
                    userId_python.append(tag['owner']['user_id'])
                if 'java' in everytag:
                    userId_java.append(tag['owner']['user_id']) # get user id
                    path_user = path_to_user+str(tag['owner']['user_id'])+'.json'
                    with open (path_user,'r') as json_file:
                        data = json.load(json_file)
                    user_badges = data['items']
                    weights = {'gold': 8, 'bronze': 2, 'silver': 4}
                    for item in user_badges:
                        try:
                            count = item['badge_counts']
                            user_reputation[item['user_id']] = item['reputation']

                            weight = 2
                            value = 0
                            for key in count:
                                value = value + weights[key] * count[key]                    
                            user_badge_count[item['user_id']] =  value #sum(count.values())
                            topweighted_questions_java[tag['title']] = value
                        except KeyError:
                            continue
                        page = page + 1

                    userId_java.append(tag['owner']['user_id'])
        except KeyError:
            continue
        except  FileNotFoundError:
            continue

print("done")

print(len(userId_python),'python tags')
print(len(userId_java), 'java tags')
print(topweighted_questions_python)
print(topweighted_questions_java)
# Out:
# done
# 7310 python tags
# 21115 java tags
# ...

# %%
toppython_sorted = sorted(topweighted_questions_python.items(), key=lambda x:x[1], reverse = True)
topjava_sorted = sorted(topweighted_questions_java.items(), key=lambda x:x[1], reverse = True)
import csv
with open('topweighted_questions_python.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in topweighted_questions_python.items():
        writer.writerow([key, value])

# %%
with open('topweighted_questions_java.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in topweighted_questions_java.items():
        writer.writerow([key, value])

# %% [markdown]
# #                                                  Analysis 2

# %% [markdown]
# # Get all the  tags associated with the user

# %%
# get tags associated with the user id
import requests
import time
path_to_json = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/TagsOfUsers/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
user_link = {}

userId_python = []
useId_java = []
for js in json_files:
    with open(os.path.join(path_to_questions, js)) as json_file:
        data = json.load(json_file)
    users = data['items']
    for tag in users:
        tags = tag['tags']
        #print(tags)
        try:
            for everytag in tags:
                if 'python' in everytag:
                    userId_python.append(tag['owner']['user_id'])
                if 'java' in tags:
                    userId_java.append(tag['owner']['user'])
        except KeyError:
            continue
            

print("done collecting ID")
for userID in userId_python:
    url = 'https://api.stackexchange.com/2.2/users/'+str(userID)+'/tags?order=desc&sort=popular&site=stackoverflow&key=f49Nam3UjMJmLs2KHr1jcg(('
    response = requests.get(url)
    response = response.json()
    with open(path_to_json+str(userID)+'.json', 'w') as f:
        json.dump(response, f)
        time.sleep(1)
print("Tags obtained for the usertags files have been saved in the folder ../TagsOfUsers")

# %% [markdown]
# # Get all the top users for the topic based on the reputation

# %%
path_to_user = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/UserProfile_For_Questions/'
user_reputation = {}

for userID in userId_python:
    with open(path_to_user+str(userID)+'.json', 'r') as json_file:
        data = json.load(json_file) 
    users = data['items']    
    for item in  users:
        user_link[item['user_id']] = item['display_name'] + " - " + item['link']
        user_reputation[item['user_id']] = item['reputation']
    
sorted_user_reputation = sorted(user_reputation.items(), key=lambda x:x[1], reverse = True)
print(sorted_user_reputation)

import csv
with open('user_reputation.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in user_reputation.items():
        writer.writerow([key, value])

# %%
print('hey')

# %% [markdown]
# # Get the user id's from

# %%
user_link = {}
path_to_json = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/UserProfile_For_Questions/'
for user in reputation_user:
    with open(path_to_json+str(user)+'.json', 'r') as json_file:
        data = json.load(json_file) 
    users = data['items']    
    for item in  users:
        user_link[user] = item['display_name'] + " - " + item['link']
    
print(len(user_link))
# Out:
# 10

# %% [markdown]
# #                                                         Analysis 3

# %% [markdown]
# # Find number of users for each badge type to see popular badges among the users

# %%
# from the badges already stored find the most popular badges
import os, json

path_to_badges = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Badges/'
json_files = [pos_json for pos_json in os.listdir(path_to_badges) if pos_json.endswith('.json')]
userlist = []
badge_dict = {}

for js in json_files:
    with open(os.path.join(path_to_badges, js)) as json_file:
        data = json.load(json_file)
    
    badges = data['items']
    #print(len(badges))
    for item in badges:
        if item['badge_type'] == 'named':
            if item['name'] in badge_dict:
                badge_dict[item['name']]  += 1 
            else:
                badge_dict[item['name']]  = 1 
           
            if item['user']['user_id'] not in userlist:
                userlist.append(item['user']['user_id'])
        
print(badge_dict)
badge_sorted = sorted(user_reputation.items(), key=lambda x:x[1], reverse = True)
print(badge_sorted)
# Out:
# {'Tumbleweed': 549, 'Supporter': 642, 'Inquisitive': 103, 'Civic Duty': 83, 'Benefactor': 79, 'Promoter': 129, 'Announcer': 41, 'Unsung Hero': 7, 'Nice Answer': 143, 'Great Answer': 5, 'Peer Review': 14, 'Altruist': 15, 'Curious': 389, 'Autobiographer': 287, 'Necromancer': 70, 'Citizen Patrol': 172, 'Critic': 318, 'Taxonomist': 4, 'Enlightened': 17, 'Nice Question': 233, 'Tenacious': 38, 'Quorum': 46, 'Informed': 304, 'Incrementalist': 16, 'Good Question': 107, 'Backer': 27, 'Beta': 4, 'Yearling': 273, 'Proofreader': 21, 'Vox Populi': 28, 'Deputy': 1, 'Caucus': 189, 'Commentator': 610, 'Knowledgeable': 1, 'Suffrage': 38, 'Fanatic': 11, 'Renovator': 1, 'Explainer': 49, 'Analytical': 36, 'Mortarboard': 34, 'Favorite Question': 45, 'Famous Question': 174, 'Bluebook': 4, 'Enthusiast': 122, 'Revival': 107, 'Notable Question': 307, 'Organizer': 118, 'Great Question': 24, 'Guru': 11, 'Strunk &amp; White': 1, 'Popular Question': 441, 'Talkative': 11, 'Excavator': 104, 'Electorate': 1, 'Revie
# ...

# %%
badge_sorted = sorted(badge_dict.items(), key=lambda x:x[1], reverse = True)
print(badge_sorted)
# Out:
# [('Editor', 799), ('Student', 788), ('Scholar', 759), ('Supporter', 642), ('Commentator', 610), ('Tumbleweed', 549), ('Teacher', 471), ('Popular Question', 441), ('Curious', 389), ('Custodian', 372), ('Critic', 318), ('Notable Question', 307), ('Informed', 304), ('Autobiographer', 287), ('Yearling', 273), ('Nice Question', 233), ('Caucus', 189), ('Famous Question', 174), ('Citizen Patrol', 172), ('Self-Learner', 166), ('Peer Pressure', 147), ('Nice Answer', 143), ('Promoter', 129), ('Enthusiast', 122), ('Organizer', 118), ('Good Question', 107), ('Revival', 107), ('Excavator', 104), ('Inquisitive', 103), ('Educated', 90), ('Civic Duty', 83), ('Benefactor', 79), ('Necromancer', 70), ('Constituent', 51), ('Cleanup', 51), ('Explainer', 49), ('Good Answer', 47), ('Quorum', 46), ('Favorite Question', 45), ('Announcer', 41), ('Tenacious', 38), ('Suffrage', 38), ('Analytical', 36), ('Mortarboard', 34), ('Tag Editor', 34), ('Investor', 30), ('Vox Populi', 28), ('Backer', 27), ('Great Questio
# ...

# %% [markdown]
# #                                                Analysis 4

# %% [markdown]
# # For each question find the tags attached

# %%
import json, os

path_to_json = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Questions/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]


tags = []
taglist = []
answers_count = {}
question_count = {}
tagcount = {}
answercount_fortag = {}
page = 0
for js in json_files:
    with open(os.path.join(path_to_json, js)) as json_file:
        data = json.load(json_file)
    users = data['items']
    for item in users:
        try:
            answers_count[item['question_id']] = item['answer_count']
            tags = item['tags']
            question_count[item['question_id']] = tags
            
            for tag in tags:
                if tag in tagcount:
                    tagcount[tag] += 1
                    
                else:
                    tagcount[tag] = 1
                    
                
                if tag in answercount_fortag:
                    answercount_fortag[tag] += item['answer_count']
                else:
                    answercount_fortag[tag] = item['answer_count']
                if tag not in taglist:
                    taglist.append(tag)
        except KeyError:
            continue
print('done')
print('Tag count')
print(tagcount)
print('answercount_fortag')
# Out:
# done
# Tag count
# ...

# %%
print(answercount_fortag)
#print(answers_count)
# Out:
# {'android-lint': 5, 'angularjs-ng-click': 21, 'inner-classes': 19, 'boot2docker': 15, 'throughput': 0, 'python-datamodel': 2, 'singleton': 48, 'php-gd': 1, 'imagettftext': 5, 'symbol': 12, 'qcachegrind': 1, 'kalman-filter': 5, 'django-pipeline': 0, 'odm': 2, 'microformats': 1, 'file-extension': 4, 'jinja2': 44, 'menustrip': 0, 'derived-class': 10, 'sql-parametrized-query': 4, 'abstract-methods': 1, 'custom-attribute': 0, 'static-linking': 3, 'codelens': 0, 'pixel': 12, 'auth-token': 1, 'owin': 39, 'eviews': 2, 'summarization': 1, 'tvcontentitem': 0, 'ibm-sterling': 3, 'type-theory': 3, 'mobile-angular-ui': 0, 'jodatime': 27, 'bitcore': 0, 'logic': 70, 'android-ndk': 75, 'ajax-polling': 0, 'types': 146, 'setbackground': 1, 'wsdl.exe': 0, 'python-importlib': 0, 'resolve': 1, 'stateless': 6, 'scripting-bridge': 0, 'unlink': 5, 'recurring-events': 2, 'worklight-server': 1, 'gravity-forms-plugin': 11, 'google-apps': 15, 'linq-to-sql': 43, 'spark-launcher': 4, 'gridview': 132, 'flume-twitt
# ...

# %%
import csv
with open('eggs.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(['Spam'] * 5 + ['Baked Beans'])
    spamwriter.writerow(['Spam', 'Lovely Spam', 'Wonderful Spam'])

# %% [markdown]
# #                                                 Analysis 5

# %%
import json, os

path_to_json = 'F:/Python_DataAnalysis_Assignments/DataAnalysisPythonRepository_001680280/MidTerm/Questions/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]


userId = []
page = 0
downvote_for_user = {}

for js in json_files:
    with open(os.path.join(path_to_json, js)) as json_file:
        data = json.load(json_file)
    users = data['items']
    for item in users:
        try:
            if item['owner']['user_id'] is not None and item['owner']['user_id'] not in userId:
                 if item['score'] < 0:
                    if item['owner']['user_id'] in downvote_for_user:
                        downvote_for_user[item['owner']['user_id']] +=  1
                    else:
                        downvote_for_user[item['owner']['user_id']] = 1

        except KeyError:
            continue

sorted_downvote = sorted(downvote_for_user.items(), key=lambda x:x[1], reverse = True)
print(sorted_downvote [:10])
# Out:
# [(4864334, 5), (7049572, 4), (6822130, 4), (6952399, 4), (1186050, 4), (6759523, 4), (7064326, 4), (6410359, 4), (6615039, 4), (5632400, 4)]

# %%
import csv
tocsv = {1:"hey", 2:"hello"}
with open('dict.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in tocsv.items():
        writer.writerow([key, value])
